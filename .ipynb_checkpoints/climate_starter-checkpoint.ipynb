# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, distinct

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite",echo=False)

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
#Hawaii = Base.classes.hawaii

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
#view the Measurement data dictionary
first_row = session.query(Measurement).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x2067b8419e8>,
#  'prcp': 0.08,
#  'date': '2010-01-01',
#  'id': 1,
#  'tobs': 65.0,
#  'station': 'USC00519397'}

# %%
#view the station data dictionary
first_row = session.query(Station).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x2067b889668>,
#  'longitude': -157.8168,
#  'name': 'WAIKIKI 717.2, HI US',
#  'id': 1,
#  'elevation': 3.0,
#  'latitude': 21.2716,
#  'station': 'USC00519397'}

# %%
st_date_str = "2017-08-23"
print(type(st_date_str))
st_date = dt.datetime.strptime(st_date_str, '%Y-%m-%d')
print(st_date)
type (st_date)
# Out:
# <class 'str'>
# 2017-08-23 00:00:00
# datetime.datetime

# %%
dateprevyr = st_date - relativedelta(years=1)

print(dateprevyr)
# Out:
# 2016-08-23 00:00:00

# %%
result = session.query(Measurement.date, Measurement.prcp).\
                filter(Measurement.date >dateprevyr)
for row in result:
    print(row.date,row.prcp)
# Out:
# 2016-08-24 0.08
# 2016-08-25 0.08
# 2016-08-26 0.0
# 2016-08-27 0.0
# 2016-08-28 0.01
# 2016-08-29 0.0
# 2016-08-30 0.0
# 2016-08-31 0.13
# 2016-09-01 0.0
# 2016-09-02 0.0
# 2016-09-03 0.0
# 2016-09-04 0.03
# 2016-09-05 None
# 2016-09-06 None
# 2016-09-07 0.05
# 2016-09-08 0.0
# 2016-09-09 0.03
# 2016-09-10 0.0
# 2016-09-11 0.05
# 2016-09-12 0.0
# 2016-09-13 0.02
# 2016-09-14 1.32
# 2016-09-15 0.42
# 2016-09-16 0.06
# 2016-09-17 0.05
# 2016-09-18 0.0
# 2016-09-19 0.0
# 2016-09-20 0.0
# 2016-09-21 0.0
# 2016-09-22 0.02
# 2016-09-23 0.0
# 2016-09-24 0.0
# 2016-09-25 0.0
# 2016-09-26 0.06
# 2016-09-27 0.02
# 2016-09-28 0.0
# 2016-09-29 0.0
# 2016-09-30 0.0
# 2016-10-01 0.0
# 2016-10-02 0.0
# 2016-10-03 0.0
# 2016-10-04 0.0
# 2016-10-05 0.0
# 2016-10-06 0.0
# 2016-10-07 0.0
# 2016-10-08 0.0
# 2016-10-09 0.0
# 2016-10-10 0.0
# 2016-10-11 0.0
# 2016-10-12 0.0
# 2016-10-13 0.0
# 2016-10-14 0.0
# 2016-10-15 0.0
# 2016-10-16 0.0
# 2016-10-17 0.01
# 2016-10-18 0.0
# 2016-10-19 0.0
# ...

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# Calculate the date 1 year ago from the last data point in the database
Date_list = []
prcp_list = []


result = session.query(Measurement.date, Measurement.prcp).\
                filter(Measurement.date >dateprevyr)
for row in result:
    print(row.date,row.prcp)
    
    Date_list.append(row.date)
    prcp_list.append(row.prcp)
    
    
    


# Perform a query to retrieve the data and precipitation scores

# Save the query results as a Pandas DataFrame and set the index to the date column

# Sort the dataframe by date

# Use Pandas Plotting with Matplotlib to plot the data
# Out:
# 2016-08-24 0.08
# 2016-08-25 0.08
# 2016-08-26 0.0
# 2016-08-27 0.0
# 2016-08-28 0.01
# 2016-08-29 0.0
# 2016-08-30 0.0
# 2016-08-31 0.13
# 2016-09-01 0.0
# 2016-09-02 0.0
# 2016-09-03 0.0
# 2016-09-04 0.03
# 2016-09-05 None
# 2016-09-06 None
# 2016-09-07 0.05
# 2016-09-08 0.0
# 2016-09-09 0.03
# 2016-09-10 0.0
# 2016-09-11 0.05
# 2016-09-12 0.0
# 2016-09-13 0.02
# 2016-09-14 1.32
# 2016-09-15 0.42
# 2016-09-16 0.06
# 2016-09-17 0.05
# 2016-09-18 0.0
# 2016-09-19 0.0
# 2016-09-20 0.0
# 2016-09-21 0.0
# 2016-09-22 0.02
# 2016-09-23 0.0
# 2016-09-24 0.0
# 2016-09-25 0.0
# 2016-09-26 0.06
# 2016-09-27 0.02
# 2016-09-28 0.0
# 2016-09-29 0.0
# 2016-09-30 0.0
# 2016-10-01 0.0
# 2016-10-02 0.0
# 2016-10-03 0.0
# 2016-10-04 0.0
# 2016-10-05 0.0
# 2016-10-06 0.0
# 2016-10-07 0.0
# 2016-10-08 0.0
# 2016-10-09 0.0
# 2016-10-10 0.0
# 2016-10-11 0.0
# 2016-10-12 0.0
# 2016-10-13 0.0
# 2016-10-14 0.0
# 2016-10-15 0.0
# 2016-10-16 0.0
# 2016-10-17 0.01
# 2016-10-18 0.0
# 2016-10-19 0.0
# ...

# %%
print(len(Date_list))
# Out:
# 2223

# %%
print(len(prcp_list))
# Out:
# 2223

# %%
date_prcp_dict ={"date": Date_list, "Precipitation": prcp_list}
#date_prcp_date

# %%
# Perform a query to retrieve the data and precipitation scores
data_df = pd.DataFrame(date_prcp_dict)
data_df.head()
# Out:
#          date  Precipitation
# 0  2016-08-24           0.08
# 1  2016-08-25           0.08
# 2  2016-08-26           0.00
# 3  2016-08-27           0.00
# 4  2016-08-28           0.01

# %%
# Sort the dataframe by date
data_df.sort_values(by=['date'], inplace=True, ascending=False)
data_df.head()
# Out:
#             date  Precipitation
# 2222  2017-08-23           0.45
# 1523  2017-08-23           0.08
# 1005  2017-08-23           0.00
# 359   2017-08-23           0.00
# 1522  2017-08-22           0.00

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
data_df.set_index(data_df['date'], inplace=True)

# %%
data_df.head()
# Out:
#                   date  Precipitation
# date
# 2017-08-23  2017-08-23           0.45
# 2017-08-23  2017-08-23           0.08
# 2017-08-23  2017-08-23           0.00
# 2017-08-23  2017-08-23           0.00
# 2017-08-22  2017-08-22           0.00

# %%
data_df.plot(x_compat=True)

# %%
data_df.plot(x="date",y="Precipitation",kind="line",ax=None,legend=True,
                    title="Hawaii - Date vs precipitation ")

# %% [markdown]
# ![precipitation](Images/precipitation.png)

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
data_df.describe()
# Out:
#        Precipitation
# count    2015.000000
# mean        0.176462
# std         0.460288
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# ![describe](Images/describe.png)

# %%
# Design a query to show how many stations are available in this dataset?
#data_df.describe().transpose()

date1_list = []
station_list = []


results = session.query(Measurement.date, Measurement.station).\
                filter(Measurement.date)
for row in results:
    print(row.date,row.station)
    
    date1_list.append(row.date)
    station_list.append(row.station)
# Out:
# 2010-01-01 USC00519397
# 2010-01-02 USC00519397
# 2010-01-03 USC00519397
# 2010-01-04 USC00519397
# 2010-01-06 USC00519397
# 2010-01-07 USC00519397
# 2010-01-08 USC00519397
# 2010-01-09 USC00519397
# 2010-01-10 USC00519397
# 2010-01-11 USC00519397
# 2010-01-12 USC00519397
# 2010-01-14 USC00519397
# 2010-01-15 USC00519397
# 2010-01-16 USC00519397
# 2010-01-17 USC00519397
# 2010-01-18 USC00519397
# 2010-01-19 USC00519397
# 2010-01-20 USC00519397
# 2010-01-21 USC00519397
# 2010-01-22 USC00519397
# 2010-01-23 USC00519397
# 2010-01-24 USC00519397
# 2010-01-25 USC00519397
# 2010-01-26 USC00519397
# 2010-01-27 USC00519397
# 2010-01-28 USC00519397
# 2010-01-30 USC00519397
# 2010-01-31 USC00519397
# 2010-02-01 USC00519397
# 2010-02-03 USC00519397
# 2010-02-04 USC00519397
# 2010-02-05 USC00519397
# 2010-02-06 USC00519397
# 2010-02-07 USC00519397
# 2010-02-08 USC00519397
# 2010-02-09 USC00519397
# 2010-02-11 USC00519397
# 2010-02-12 USC00519397
# 2010-02-13 USC00519397
# 2010-02-14 USC00519397
# ...

# %%
print(len(date1_list))
# Out:
# 19550

# %%
station_measurement_dict ={"Most Active Station": date1_list, "Station": station_list}

# %%
df1 = pd.DataFrame(station_measurement_dict)
df1.head()
# Out:
#   Most Active Station      Station
# 0          2010-01-01  USC00519397
# 1          2010-01-02  USC00519397
# 2          2010-01-03  USC00519397
# 3          2010-01-04  USC00519397
# 4          2010-01-06  USC00519397

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
df2 = df1.groupby(['Station']).count()
df2.sort_values(by="Most Active Station",ascending=False)
# Out:
#              Most Active Station
# Station
# USC00519281                 2772
# USC00519397                 2724
# USC00513117                 2709
# USC00519523                 2669
# USC00516128                 2612
# USC00514830                 2202
# USC00511918                 1979
# USC00517948                 1372
# USC00518838                  511

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.

# %%
#Start here
ID_list = []
Station_list = []
Date_list = []
tobs_list = []


result_tobs = session.query(Measurement.id,Measurement.station, Measurement.date, Measurement.tobs).\
                filter(Measurement.date >dateprevyr)
for row in result_tobs:
    print(row.id, row.station,row.date,row.tobs)
    
    ID_list.append(row.id)
    Station_list.append(row.station)
    Date_list.append(row.date)
    tobs_list.append(row.tobs)
# Out:
# 2365 USC00519397 2016-08-24 79.0
# 2366 USC00519397 2016-08-25 80.0
# 2367 USC00519397 2016-08-26 79.0
# 2368 USC00519397 2016-08-27 77.0
# 2369 USC00519397 2016-08-28 78.0
# 2370 USC00519397 2016-08-29 78.0
# 2371 USC00519397 2016-08-30 79.0
# 2372 USC00519397 2016-08-31 80.0
# 2373 USC00519397 2016-09-01 81.0
# 2374 USC00519397 2016-09-02 80.0
# 2375 USC00519397 2016-09-03 79.0
# 2376 USC00519397 2016-09-04 75.0
# 2377 USC00519397 2016-09-05 79.0
# 2378 USC00519397 2016-09-06 76.0
# 2379 USC00519397 2016-09-07 76.0
# 2380 USC00519397 2016-09-08 80.0
# 2381 USC00519397 2016-09-09 79.0
# 2382 USC00519397 2016-09-10 78.0
# 2383 USC00519397 2016-09-11 76.0
# 2384 USC00519397 2016-09-12 78.0
# 2385 USC00519397 2016-09-13 78.0
# 2386 USC00519397 2016-09-14 75.0
# 2387 USC00519397 2016-09-15 79.0
# 2388 USC00519397 2016-09-16 80.0
# 2389 USC00519397 2016-09-17 79.0
# 2390 USC00519397 2016-09-18 81.0
# 2391 USC00519397 2016-09-19 77.0
# 2392 USC00519397 2016-09-20 77.0
# ...

# %%
print(len(ID_list))
# Out:
# 2223

# %%
print(len(Date_list))
# Out:
# 2223

# %%
temperature_measurement_dict ={"Station ID": ID_list,"Station": Station_list, "Temperature Date": Date_list, "Temperature": tobs_list}

# %%
df_3 = pd.DataFrame.from_dict(temperature_measurement_dict,orient='index')
df_3.transpose()
# Out:
#      Station ID      Station Temperature Date Temperature
# 0          2365  USC00519397       2016-08-24          79
# 1          2366  USC00519397       2016-08-25          80
# 2          2367  USC00519397       2016-08-26          79
# 3          2368  USC00519397       2016-08-27          77
# 4          2369  USC00519397       2016-08-28          78
# 5          2370  USC00519397       2016-08-29          78
# 6          2371  USC00519397       2016-08-30          79
# 7          2372  USC00519397       2016-08-31          80
# 8          2373  USC00519397       2016-09-01          81
# 9          2374  USC00519397       2016-09-02          80
# 10         2375  USC00519397       2016-09-03          79
# 11         2376  USC00519397       2016-09-04          75
# 12         2377  USC00519397       2016-09-05          79
# 13         2378  USC00519397       2016-09-06          76
# 14         2379  USC00519397       2016-09-07          76
# ...

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?
np.min(tobs_list),np.max(tobs_list),np.mean(tobs_list)
# Out:
# (58.0, 87.0, 74.57894736842105)

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# %% [markdown]
# ![precipitation](Images/station-histogram.png)

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
# Out:
# 62.0 68.36585365853658 74.0

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
# Out:
# [('USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4, 0.31), ('USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9, 0.25), ('USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6, 0.1), ('USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6, 0.060000000000000005), ('USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9, 0.0), ('USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0, 0.0), ('USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9, 0.0), ('USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0, 0.0), ('USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5, 0.0)]

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date
# Out:
# [(62.0, 69.15384615384616, 77.0),
#  (60.0, 69.39622641509433, 77.0),
#  (62.0, 68.9090909090909, 77.0),
#  (58.0, 70.0, 76.0),
#  (56.0, 67.96428571428571, 76.0),
#  (61.0, 68.96491228070175, 76.0),
#  (57.0, 68.54385964912281, 76.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
# Out:
#             tmin       tavg  tmax
# date
# 2018-01-01  62.0  69.153846  77.0
# 2018-01-02  60.0  69.396226  77.0
# 2018-01-03  62.0  68.909091  77.0
# 2018-01-04  58.0  70.000000  76.0
# 2018-01-05  56.0  67.964286  76.0

# %%
# Plot the daily normals as an area plot with `stacked=False`
# Out:
# <img src="data:image/png;base64,..." width="640">
